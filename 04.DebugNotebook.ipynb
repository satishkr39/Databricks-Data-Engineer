# %% [markdown]
# ## Debug of python notebook
# - Breakpoint
# - Variable inspection
# - Console window
# - line by line execution
#
# ## to enable : settings > developer > Enable interactive debugger

# %%
# to enable the debug: click on the dropdown of the cell and select Debug cell

price = 120
tax = 10
discount = 5
quantity = 100

total_sell = price * quantity

sell_after_tax = total_sell - (total_sell * (10/100))

print(sell_after_tax)

print(total_sell)
